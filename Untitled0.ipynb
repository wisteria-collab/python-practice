# %% [markdown]
# <a href="https://colab.research.google.com/github/wisteria-collab/python-practice/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
first = input( "最初の数字を入力してください")
next = input("次の数字を入力してください")
result_puls= int(first) + int(next)
print(result_puls)
result_minus= int(first) - int(next)
print(result_minus)
result_times= int(first) * int(next)
print(result_times)
result_divide= int(first) / int(next)
print(result_divide)
# Out:
# 最初の数字を入力してくださいあ
# 次の数字を入力してくださいい
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_168/1004260716.py in <cell line: 0>()
#       1 first = input( "最初の数字を入力してください")
#       2 next = input("次の数字を入力してください")
# ----> 3 result_puls= int(first) + int(next)
#       4 print(result_puls)
#       5 result_minus= int(first) - int(next)
#
# ValueError: invalid literal for int() with base 10: 'あ'

# %%
first = input( "最初の数字を入力してください")
next = input("次の数字を入力してください")
result_puls= int(first) + int(next)
result_minus= int(first) - int(next)
result_times= int(first) * int(next)
result_divide= int(first) / int(next)
print(f"足し算の結果:{result_puls}引き算の結果:{result_minus}掛け算の結果:{result_times}割り算の結果:{result_divide}")
# Out:
# 足し算の結果:4
# 引き算の結果:0掛け算の結果:4割り算の結果:1.0

# %%
person = {
    "name": "田中",
    "age": 22,
    "score":80
    }

print(person["name"])
print(person["age"])
print(person["score"])
# Out:
# 田中
# 22
# 80

# %%
person = {
    "name": "田中",
    "age": 22,
    "hometown": "埼玉"
    }

print("名前:"+ person["name"])
print("年齢:"+ str(person["age"]))
print("出身:"+ person["hometown"])
# Out:
# 名前:田中
# 年齢:22
# 出身:埼玉

# %%
person = {
    "name": "田中",
    "age": 22,
    "hometown": "埼玉"
}

for key, value in person.items():
    print(key + "：" + str(value))
# Out:
# name：田中
# age：22
# hometown：埼玉

# %%
name = "田中"
age = 22
score = 80

print(f"{name}さんは{age}歳で、点数は{score}点です。")
# Out:
# 田中さんは22歳で、点数は80点です。

# %%
count = 0

while count < 5:
  print(f"カウント：{count}")
  count = count + 1

print("終了")
# Out:
# カウント：0
# カウント：1
# カウント：2
# カウント：3
# カウント：4
# 終了

# %%
passward = "python"
write = input("パスワードを入力してください")
while passward != write:
  print("違います。もう一度入力してください")
  write = input("パスワードを入力してください")
print("正解です！")
# Out:
# パスワードを入力してくださいsd
# 違います。もう一度入力してください
# パスワードを入力してくださいpython
# 正解です！

# %%
# ファイルに書き込む
with open("test.txt" , "w") as f:
  f.write("こんにちは\n")
  f.write("Pythonでファイルを作りました\n")

print("保存しました")
# Out:
# 保存しました

# %%
with open("test.txt", "r") as f:
    content = f.read()
    print(content)
# Out:
# こんにちは
# Pythonでファイルを作りました

# %%
with open("memo.txt" , "a") as f:
  memo = input("メモを入力してください")
  f.write(memo + "\n")
print("保存しました")
# Out:
# メモを入力してください2
# 保存しました

# %%
try:
    first = input("数字を入力してください")
    print(int(first))
except ValueError:
    print("数字を入力してください！")
# Out:
# 数字を入力してくださいあ
# 数字を入力してください！

# %%
try:
  first = input("最初の数字を入力してください")
  next = input("次の数字を入力してください")
  result_plus = int(first) + int(next)
  result_minus = int(first) - int(next)
  result_times = int(first) * int(next)
  result_divide = int(first) / int(next)
  print(f"足し算の結果：{result_plus}\n引き算の結果：{result_minus}\n掛け算の結果：{result_times}\n割り算の結果：{result_divide}")

except ValueError:
  print("数値を入力してください！")
except ZeroDivisionError:
    print("0では割れません！")
# Out:
# 最初の数字を入力してくださいa
# 次の数字を入力してくださいa
# 数値を入力してください！

# %%
try:
    print(10 / 0)
except ZeroDivisionError:
    print("0では割れません！")
# Out:
# 0では割れません！
